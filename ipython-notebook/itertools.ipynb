# %%
from itertools import *

x_list = count(5, 2)

c_list = cycle('xyz')

r_list = repeat(1.2)

nr_list = repeat(1.2, 5)

# cnt = 0
#
# for c in nr_list:
#     if cnt == 20:
#         break
#     print c
#     cnt += 1

rlt = imap(pow, [1, 2, 3], [1, 2, 3])

srlt = starmap(pow, [(1, 1), (2, 2), (3, 3)])

ifl = ifilter(lambda x: x > 5, [2, 3, 5, 6, 7])

iflf = ifilterfalse(lambda x: x > 5, [2, 3, 5, 6, 7])

tw = takewhile(lambda x: x < 5, [1, 3, 6, 7, 1])

dw = dropwhile(lambda x: x < 5, [1, 3, 6, 7, 1])

ch = chain([1, 2, 3], [4, 5, 7])

print type(ch)

for m, n in product('abc', [1, 2]):
    print m, n

ct = combinations(['wangxiao', 'zhikang', 'peiyou'], 2)
for x, y in ct:
    print x, y

cwr = combinations_with_replacement('abc', 2)
for x, y in cwr:
    print x, y


def height_class(h):
    if h > 180:
        return "tall"
    elif h < 160:
        return "short"
    else:
        return "middle"


friends = [191, 158, 159, 165, 170, 177, 181, 182, 190]

friends = sorted(friends, key=height_class)
for m, n in groupby(friends, key=height_class):
    print(m)
    print(list(n))


cp = compress('ABCD', [1, 1, 1, 0])
for c in cp:
    print c
